# %%
import pandas as pd

AE = pd.read_csv('~/Documentos/tomate/tablasLuisa/heterosis/paperLuisa/expancion2/CorrActividadEnzimatica/ActividadEnzimatica.csv')

met = pd.read_csv('~/Documentos/tomate/tablasLuisa/heterosis/paperLuisa/expancion2/CorrMetabolitos/metabolitos.csv')

print(AE.shape , met.shape)

#[A = (P1-P2)/2]

#[D = H-((P1+P2)/2)]

#Levovil (P1) x Cervil (P2), LA0147 (P1) x Plovdiv (P2) and Ferum (P1) x LA1420 (P2)
# Out:
# (26, 25) (26, 26)

# %%
#vamos a organizar los dataset, asi trabajo mejor

AE.columns
# Out:
# Index(['enzima', 'CervilMeanCE', 'CervilMeanOR', 'LevovilxCervilMeanCE',
#        'LevovilxCervilMeanOR', 'LevovilMeanCE', 'LevovilMeanOR',
#        'CriolloMeanCE', 'CriolloMeanOR', 'SPRxCriolloMeanCE',
#        'SPRxCriolloMeanOR', 'SPRMeanCE', 'SPRMeanOR', 'PlovdivMeanCE',
#        'PlovdivMeanOR', 'LA0147xPlovdivMeanCE', 'LA0147xPlovdivMeanOR',
#        'LA0147MeanCE', 'LA0147MeanOR', 'LA1420MeanCE', 'LA1420MeanOR',
#        'FerumxLA1420MeanCE', 'FerumxLA1420MeanOR', 'FerumMeanCE',
#        'FerumMeanOR'],
#       dtype='object')

# %%
AE_CE = AE.loc[: , ['enzima', 'CervilMeanCE', 'LevovilxCervilMeanCE','LevovilMeanCE','PlovdivMeanCE',
 'LA0147xPlovdivMeanCE','LA0147MeanCE', 'LA1420MeanCE','FerumxLA1420MeanCE','FerumMeanCE']]

AE_OR = AE.loc[: , ['enzima', 'CervilMeanOR', 'LevovilxCervilMeanOR','LevovilMeanOR','PlovdivMeanOR',
 'LA0147xPlovdivMeanOR','LA0147MeanOR', 'LA1420MeanOR','FerumxLA1420MeanOR','FerumMeanOR']]

# %%
#lo mismo para met

# %%
met.columns
# Out:
# Index(['metabolito', 'tipo', 'CervilMeanCE', 'CervilMeanOR',
#        'LevovilxCervilMeanCE', 'LevovilxCervilMeanOR', 'LevovilMeanCE',
#        'LevovilMeanOR', 'CriolloMeanCE', 'CriolloMeanOR', 'SPRxCriolloMeanCE',
#        'SPRxCriolloMeanOR', 'SPRMeanCE', 'SPRMeanOR', 'PlovdivMeanCE',
#        'PlovdivMeanOR', 'LA0147xPlovdivMeanCE', 'LA0147xPlovdivMeanOR',
#        'LA0147MeanCE', 'LA0147MeanOR', 'LA1420MeanCE', 'LA1420MeanOR',
#        'FerumxLA1420MeanCE', 'FerumxLA1420MeanOR', 'FerumMeanCE',
#        'FerumMeanOR'],
#       dtype='object')

# %%
met.head(5)
# Out:
#   metabolito         tipo  CervilMeanCE  CervilMeanOR  LevovilxCervilMeanCE  \
# 0        Glc  aminoacidos       68996.3      165053.5              124058.2
# 1        Suc  aminoacidos        8649.4       28049.8                9933.0
# 2        Fru  aminoacidos       65853.1      174690.1              121465.1
# 3        Ala  aminoacidos        1356.3         246.0                 850.6
# 4        Asn  aminoacidos        2461.9        3064.0                2271.9
#
#    LevovilxCervilMeanOR  LevovilMeanCE  LevovilMeanOR  CriolloMeanCE  \
# 0              191668.3       193536.8       222922.4       123988.2
# 1               17264.7         7616.3         7596.8         6417.2
# 2              196136.4       198775.3       238532.6       121501.0
# 3                 235.7          574.8          492.6          635.7
# 4                2379.9         1360.0         2994.3         1724.6
#
#    CriolloMeanOR  ...  LA0147xPlovdivMeanCE  LA0147xPlovdivMeanOR  \
# ...

# %%
met_CE = met.loc[: , ['metabolito', 'CervilMeanCE','LevovilxCervilMeanCE','LevovilMeanCE','PlovdivMeanCE',
'LA0147xPlovdivMeanCE','LA0147MeanCE','LA1420MeanCE','FerumxLA1420MeanCE','FerumMeanCE']]

met_OR = met.loc[: , ['metabolito', 'CervilMeanOR','LevovilxCervilMeanOR','LevovilMeanOR','PlovdivMeanOR',
'LA0147xPlovdivMeanOR','LA0147MeanOR','LA1420MeanOR','FerumxLA1420MeanOR','FerumMeanOR']]

# %%
#vamos a comenzar...

#[A = (P1-P2)/2]

#[D = H-((P1+P2)/2)]

#Levovil (P1) x Cervil (P2), LA0147 (P1) x Plovdiv (P2) and Ferum (P1) x LA1420 (P2)

AE_CE.columns
# Out:
# Index(['enzima', 'CervilMeanCE', 'LevovilxCervilMeanCE', 'LevovilMeanCE',
#        'PlovdivMeanCE', 'LA0147xPlovdivMeanCE', 'LA0147MeanCE', 'LA1420MeanCE',
#        'FerumxLA1420MeanCE', 'FerumMeanCE'],
#       dtype='object')

# %%
her_AE_CE = pd.DataFrame(columns=['enzima' , 'A_LxC' , 'D_LxC' , 'D/A_LxC' ,'A_LA0147xP' , 'D_LA0147xP',
'D/A_LA0147xP', 'A_FxLA1420' , 'D_FxLA1420', 'D/A_FxLA1420'])

her_AE_OR = pd.DataFrame(columns=['enzima' , 'A_LxC' , 'D_LxC' ,'D/A_LxC' , 'A_LA0147xP' , 'D_LA0147xP',
'D/A_LA0147xP','A_FxLA1420' , 'D_FxLA1420' , 'D/A_FxLA1420'])

her_met_CE = pd.DataFrame(columns=['metabolito' , 'A_LxC' , 'D_LxC' ,'D/A_LxC' , 'A_LA0147xP' , 'D_LA0147xP', 
'D/A_LA0147xP','A_FxLA1420' , 'D_FxLA1420' , 'D/A_FxLA1420'])

her_met_OR = pd.DataFrame(columns=['metabolito' , 'A_LxC' , 'D_LxC' ,'D/A_LxC' , 'A_LA0147xP' , 'D_LA0147xP', 
'D/A_LA0147xP', 'A_FxLA1420' , 'D_FxLA1420' , 'D/A_FxLA1420'])

her_met_OR.columns
# Out:
# Index(['metabolito', 'A_LxC', 'D_LxC', 'D/A_LxC', 'A_LA0147xP', 'D_LA0147xP',
#        'D/A_LA0147xP', 'A_FxLA1420', 'D_FxLA1420', 'D/A_FxLA1420'],
#       dtype='object')

# %%
her_AE_CE['enzima'] = AE['enzima']

her_AE_OR['enzima'] = AE['enzima']

her_met_CE['metabolito'] = met['metabolito']

her_met_OR['metabolito'] = met['metabolito']

her_met_OR['metabolito']
# Out:
# 0         Glc
# 1         Suc
# 2         Fru
# 3         Ala
# 4         Asn
# 5         Asp
# 6         Abu
# 7         Gln
# 8         Ile
# 9         Leu
# 10        Phe
# 11        Tyr
# 12        Val
# 13        Thr
# 14        Asc
# 15        Cit
# 16        Mlt
# 17        Fum
# 18       Tom*
# 19     DHTom*
# 20    OH-Lyc*
# 21      5CQA*
# 22      3CQA*
# 23       Nch*
# 24       Rut*
# 25      RutP*
# Name: metabolito, dtype: object

# %%
AE_OR.columns
# Out:
# Index(['enzima', 'CervilMeanOR', 'LevovilxCervilMeanOR', 'LevovilMeanOR',
#        'PlovdivMeanOR', 'LA0147xPlovdivMeanOR', 'LA0147MeanOR', 'LA1420MeanOR',
#        'FerumxLA1420MeanOR', 'FerumMeanOR'],
#       dtype='object')

# %%
#[A = (P1-P2)/2]

#[D = H-((P1+P2)/2)]

#Levovil (P1) x Cervil (P2), LA0147 (P1) x Plovdiv (P2) and Ferum (P1) x LA1420 (P2)
#aca aggrego el A_geno.abs() para hebitar incordios con los signos
#para LxC , AE

her_AE_CE['A_LxC'] = ((AE_CE['LevovilMeanCE'] - AE_CE['CervilMeanCE'])/2)

her_AE_CE['A_LxC'] = her_AE_CE['A_LxC'].abs()

her_AE_CE['D_LxC'] = (AE_CE['LevovilxCervilMeanCE'] - ((AE_CE['LevovilMeanCE'] + AE_CE['CervilMeanCE'])/2))

#para LxC , met

her_met_CE['A_LxC'] = ((met_CE['LevovilMeanCE'] - met_CE['CervilMeanCE'])/2)

her_met_CE['A_LxC'] = her_met_CE['A_LxC'].abs()

her_met_CE['D_LxC'] = (met_CE['LevovilxCervilMeanCE'] - ((met_CE['LevovilMeanCE'] + met_CE['CervilMeanCE'])/2))

#LA0147xPlovdiv

#para AE

her_AE_CE['A_LA0147xP'] = ((AE_CE['LA0147MeanCE'] - AE_CE['PlovdivMeanCE'])/2)

her_AE_CE['A_LA0147xP'] = her_AE_CE['A_LA0147xP'].abs()

her_AE_CE['D_LA0147xP'] = (AE_CE['LA0147xPlovdivMeanCE'] - ((AE_CE['LA0147MeanCE'] + AE_CE['PlovdivMeanCE'])/2))

#para met

her_met_CE['A_LA0147xP'] = ((met_CE['LA0147MeanCE'] - met_CE['PlovdivMeanCE'])/2)

her_met_CE['A_LA0147xP'] = her_met_CE['A_LA0147xP'].abs()

her_met_CE['D_LA0147xP'] = (met_CE['LA0147xPlovdivMeanCE'] - ((met_CE['LA0147MeanCE'] + met_CE['PlovdivMeanCE'])/2))

#FerumxLA1420

#para AE

her_AE_CE['A_FxLA1420'] = ((AE_CE['FerumMeanCE'] - AE_CE['LA1420MeanCE'])/2)

her_AE_CE['A_FxLA1420'] = her_AE_CE['A_FxLA1420'].abs()

her_AE_CE['D_FxLA1420'] = (AE_CE['FerumxLA1420MeanCE'] - ((AE_CE['FerumMeanCE'] + AE_CE['LA1420MeanCE'])/2))

#para met

her_met_CE['A_FxLA1420'] = ((met_CE['FerumMeanCE'] - met_CE['LA1420MeanCE'])/2)

her_met_CE['A_FxLA1420'] = her_met_CE['A_FxLA1420'].abs()

her_met_CE['D_FxLA1420'] = (met_CE['FerumxLA1420MeanCE'] - ((met_CE['FerumMeanCE'] + met_CE['LA1420MeanCE'])/2))

#####para OR#####

#para LxC , AE

her_AE_OR['A_LxC'] = ((AE_OR['LevovilMeanOR'] - AE_OR['CervilMeanOR'])/2)

her_AE_OR['A_LxC'] = her_AE_OR['A_LxC'].abs()

her_AE_OR['D_LxC'] = (AE_OR['LevovilxCervilMeanOR'] - ((AE_OR['LevovilMeanOR'] + AE_OR['CervilMeanOR'])/2))

#para LxC , met

her_met_OR['A_LxC'] = ((met_OR['LevovilMeanOR'] - met_OR['CervilMeanOR'])/2)

her_met_OR['A_LxC'] = her_met_OR['A_LxC'].abs()

her_met_OR['D_LxC'] = (met_OR['LevovilxCervilMeanOR'] - ((met_OR['LevovilMeanOR'] + met_OR['CervilMeanOR'])/2))

#LA0147xPlovdiv

#para AE

her_AE_OR['A_LA0147xP'] = ((AE_OR['LA0147MeanOR'] - AE_OR['PlovdivMeanOR'])/2)

her_AE_OR['A_LA0147xP'] = her_AE_OR['A_LA0147xP'].abs()

her_AE_OR['D_LA0147xP'] = (AE_OR['LA0147xPlovdivMeanOR'] - ((AE_OR['LA0147MeanOR'] + AE_OR['PlovdivMeanOR'])/2))

#para met

her_met_OR['A_LA0147xP'] = ((met_OR['LA0147MeanOR'] - met_OR['PlovdivMeanOR'])/2)

her_met_OR['A_LA0147xP'] = her_met_OR['A_LA0147xP'].abs()

her_met_OR['D_LA0147xP'] = (met_OR['LA0147xPlovdivMeanOR'] - ((met_OR['LA0147MeanOR'] + met_OR['PlovdivMeanOR'])/2))

#FerumxLA1420

#para AE

her_AE_OR['A_FxLA1420'] = ((AE_OR['FerumMeanOR'] - AE_OR['LA1420MeanOR'])/2)

her_AE_OR['A_FxLA1420'] = her_AE_OR['A_FxLA1420'].abs()

her_AE_OR['D_FxLA1420'] = (AE_OR['FerumxLA1420MeanOR'] - ((AE_OR['FerumMeanOR'] + AE_OR['LA1420MeanOR'])/2))

#para met

her_met_OR['A_FxLA1420'] = ((met_OR['FerumMeanOR'] - met_OR['LA1420MeanOR'])/2)

her_met_OR['A_FxLA1420'] = her_met_OR['A_FxLA1420'].abs()

her_met_OR['D_FxLA1420'] = (met_OR['FerumxLA1420MeanOR'] - ((met_OR['FerumMeanOR'] + met_OR['LA1420MeanOR'])/2))

#siguen los ratios

#LxC

her_AE_CE['D/A_LxC'] = (her_AE_CE['D_LxC']/her_AE_CE['A_LxC'])

her_met_CE['D/A_LxC'] = (her_met_CE['D_LxC']/her_met_CE['A_LxC'])

her_AE_OR['D/A_LxC'] = (her_AE_OR['D_LxC']/her_AE_OR['A_LxC'])

her_met_OR['D/A_LxC'] = (her_met_OR['D_LxC']/her_met_OR['A_LxC'])

#LA0147xP

her_AE_CE['D/A_LA0147xP'] = (her_AE_CE['D_LA0147xP']/her_AE_CE['A_LA0147xP'])

her_met_CE['D/A_LA0147xP'] = (her_met_CE['D_LA0147xP']/her_met_CE['A_LA0147xP'])

her_AE_OR['D/A_LA0147xP'] = (her_AE_OR['D_LA0147xP']/her_AE_OR['A_LA0147xP'])

her_met_OR['D/A_LA0147xP'] = (her_met_OR['D_LA0147xP']/her_met_OR['A_LA0147xP'])

#FxLA1420

her_AE_CE['D/A_FxLA1420'] = (her_AE_CE['D_FxLA1420']/her_AE_CE['A_FxLA1420'])

her_met_CE['D/A_FxLA1420'] = (her_met_CE['D_FxLA1420']/her_met_CE['A_FxLA1420'])

her_AE_OR['D/A_FxLA1420'] = (her_AE_OR['D_FxLA1420']/her_AE_OR['A_FxLA1420'])

her_met_OR['D/A_FxLA1420'] = (her_met_OR['D_FxLA1420']/her_met_OR['A_FxLA1420'])

her_met_OR.head(50)
# Out:
#    metabolito      A_LxC      D_LxC    D/A_LxC  A_LA0147xP  D_LA0147xP  \
# 0         Glc   28934.45   -2319.65  -0.080169    16015.80    16940.10
# 1         Suc   10226.50    -558.60  -0.054623     2477.05     -725.05
# 2         Fru   31921.25  -10474.95  -0.328150      149.00    17010.90
# 3         Ala     123.30    -133.60  -1.083536       11.60      -83.00
# 4         Asn      34.85    -649.25 -18.629842      202.70     -967.50
# 5         Asp     612.35    -238.45  -0.389401      112.15     -322.25
# 6         Abu    1134.25     425.25   0.374917      854.30    -1367.30
# 7         Gln    2360.90    -580.50  -0.245881     2154.35    -6952.95
# 8         Ile     118.65      65.55   0.552465      200.55     -254.45
# 9         Leu      87.95     -15.35  -0.174531      196.30     -420.00
# 10        Phe     128.25    -601.65  -4.691228     2720.50    -1929.70
# 11        Tyr      23.25     -72.65  -3.124731      207.25     -237.15
# ...

# %%
her_AE_OR.head(50)
# Out:
#           enzima     A_LxC      D_LxC    D/A_LxC  A_LA0147xP  D_LA0147xP  \
# 0           PEPC     81.40     615.30   7.558968     1256.55     -509.85
# 1            ALS   1468.20     115.40   0.078600    -2875.05     4973.25
# 2          G6PDH    156.30    -152.90  -0.978247      159.00      -18.70
# 3            PGM   2149.00   -3237.70  -1.506608      783.85     1863.65
# 4             PK   1090.45   -1507.05  -1.382044      345.25      131.95
# 5        Ppi-PFK   2029.55     -47.45  -0.023380      504.10      718.30
# 6            ACO     23.40     514.40  21.982906      104.00      248.60
# 7        ATP-PFK    167.70    -418.50  -2.495528        2.70      205.50
# 8            FRK    256.25    -154.05  -0.601171     -172.65      891.55
# 9           InvN     39.90     772.20  19.353383     -612.05     2032.45
# 10          InvA   1247.65    4683.65   3.753977    -2344.60      -51.20
# 11       NAD-MDH  37709.40   -9295.40  -0.246501    13461.40      604.10
# ...

# %%
her_AE_CE.to_csv('herencia_ActEnz_CE.csv')

her_AE_OR.to_csv('herencia_ActEnz_OR.csv')

her_met_CE.to_csv('herencia_metabolito_CE.csv')

her_met_OR.to_csv('herencia_metabolito_OR.csv')

# %%
her_AE_CE.head(5)
# Out:
#   enzima    A_LxC    D_LxC   D/A_LxC  A_LA0147xP  D_LA0147xP  D/A_LA0147xP  \
# 0   PEPC   764.55  1010.45  1.321627      -28.25     3009.35   -106.525664
# 1    ALS -6134.75  2036.25 -0.331921     -142.60    10064.70    -70.579944
# 2  G6PDH   147.50   -54.30 -0.368136       70.05      257.45      3.675232
# 3    PGM  -596.20  2548.50 -4.274572     -356.90     5834.10    -16.346596
# 4     PK   182.30  -701.90 -3.850247     -620.15        5.95     -0.009594
#
#    A_FxLA1420  D_FxLA1420  D/A_FxLA1420
# 0      188.75     3689.25     19.545695
# 1     -110.05     6210.55    -56.433894
# 2      167.70      875.30      5.219439
# 3     2050.85     9024.35      4.400297
# 4     -493.60     2508.70     -5.082455

# %%
her_AE_CE['D/A_LxC'].plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
her_AE_CE['D/A_LA0147xP'].plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
her_AE_CE['D/A_FxLA1420'].plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import seaborn as sns

sns.pairplot(her_AE_CE)

# %%
her_AE_CE['D/A_LxC'].quantile([0.05 , 0.1 , 0.2 , 0.25 , 0.3 , 0.35 , 0.5 , 0.8 , 0.95])
#cerca del 20% mas alto quedarian como sobredominantes, y  cerca del 30% mas bajo quedarian como sobreresesivos
# Out:
# 0.05   -4.171302
# 0.10   -3.855869
# 0.20   -2.780730
# 0.25   -2.643605
# 0.30   -2.095542
# 0.35   -1.596034
# 0.50   -0.271358
# 0.80    1.278449
# 0.95    2.181168
# Name: D/A_LxC, dtype: float64

# %%
sns.pairplot(her_met_CE)

# %%
her_met_CE['D/A_LxC'].plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
her_met_CE['D/A_LA0147xP'].plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
her_met_CE['D/A_FxLA1420'].plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.pairplot(her_AE_OR)

# %%
her_AE_OR['D/A_LxC'].plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
her_AE_OR['D/A_LA0147xP'].plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
her_AE_OR['D/A_FxLA1420'].plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.pairplot(her_met_OR)

# %%
her_met_OR['D/A_LxC'].plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
her_met_OR['D/A_LA0147xP'].plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
her_met_OR['D/A_FxLA1420'].plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#voy a ver el temita cuantiles, para ir coparando

print(her_AE_CE['D/A_LxC'].quantile([0.05 , 0.1 , 0.2 , 0.25 , 0.3 , 0.35 , 0.5 , 0.8 , 0.95]) ,
her_AE_OR['D/A_LxC'].quantile([0.05 , 0.1 , 0.2 , 0.25 , 0.3 , 0.35 , 0.5 , 0.7,0.8 , 0.95]))
# Out:
# 0.05   -4.171302
# 0.10   -3.855869
# 0.20   -2.780730
# 0.25   -2.643605
# 0.30   -2.095542
# 0.35   -1.596034
# 0.50   -0.271358
# 0.80    1.278449
# 0.95    2.181168
# Name: D/A_LxC, dtype: float64 0.05   -3.426748
# 0.10   -1.870996
# 0.20   -0.775071
# 0.25   -0.621490
# 0.30   -0.127182
# 0.35   -0.002115
# 0.50    0.200785
# 0.70    1.444326
# 0.80    2.400562
# 0.95    7.635732
# Name: D/A_LxC, dtype: float64

# %%
print(her_AE_CE['D/A_LA0147xP'].quantile([0.05 , 0.1 , 0.2 , 0.25 , 0.3 , 0.35 , 0.5,0.6 ,0.65,0.7,0.8 ,0.95]) ,
her_AE_OR['D/A_LA0147xP'].quantile([0.05 , 0.1 , 0.2 , 0.25 , 0.3 , 0.35 , 0.5 ,0.7,0.8 , 0.95]))
# Out:
# 0.05   -62.508420
# 0.10   -27.320223
# 0.20    -6.569174
# 0.25    -2.588861
# 0.30    -1.296477
# 0.35    -0.092353
# 0.50     0.630172
# 0.60     1.086551
# 0.65     1.726621
# 0.70     2.099120
# 0.80     3.448648
# 0.95     5.238313
# Name: D/A_LA0147xP, dtype: float64 0.05   -5.547267
# 0.10   -4.242320
# 0.20   -1.442667
# 0.25   -1.232489
# 0.30   -0.521753
# 0.35   -0.189646
# 0.50    0.250405
# 0.70    1.611138
# 0.80    1.780260
# 0.95    3.499667
# Name: D/A_LA0147xP, dtype: float64

# %%
print(her_AE_CE['D/A_FxLA1420'].quantile([0.05 , 0.1 , 0.2 , 0.25 , 0.3 , 0.35 , 0.5,0.6 ,0.65,0.7,0.8 ,0.95]) ,
her_AE_OR['D/A_FxLA1420'].quantile([0.05 , 0.1 , 0.2 , 0.25 , 0.3 , 0.35 , 0.5 ,0.7,0.8 , 0.95]))
# Out:
# 0.05    -8.563977
# 0.10    -6.240938
# 0.20    -3.436907
# 0.25    -2.776622
# 0.30    -1.922745
# 0.35    -1.403483
# 0.50     0.751209
# 0.60     1.415558
# 0.65     1.856336
# 0.70     3.038853
# 0.80     5.219439
# 0.95    41.114793
# Name: D/A_FxLA1420, dtype: float64 0.05   -4.865431
# 0.10   -3.948801
# 0.20   -2.509277
# 0.25   -1.774150
# 0.30   -1.363666
# 0.35   -1.023994
# 0.50   -0.017149
# 0.70    0.929915
# 0.80    1.881332
# 0.95    6.950259
# Name: D/A_FxLA1420, dtype: float64

# %%
print(her_met_CE['D/A_LxC'].quantile([0.05,0.1,0.12,0.2 ,0.25,0.3 , 0.35 , 0.5,0.6 ,0.65,0.7,0.8 ,0.95,0.96]) ,
her_met_OR['D/A_LxC'].quantile([0.05,0.1 ,0.11, 0.2 , 0.25 , 0.3 , 0.35 , 0.5 ,0.7,0.8 , 0.95]))
# Out:
# 0.05   -3.012878
# 0.10   -1.324660
# 0.12   -1.052652
# 0.20   -0.879518
# 0.25   -0.640030
# 0.30   -0.520928
# 0.35   -0.387307
# 0.50   -0.139499
# 0.60    0.121396
# 0.65    0.165891
# 0.70    0.275319
# 0.80    0.436272
# 0.95    0.982111
# 0.96    1.010471
# Name: D/A_LxC, dtype: float64 0.05   -3.038345
# 0.10   -1.931362
# 0.11   -1.507449
# 0.20   -0.774648
# 0.25   -0.289745
# 0.30   -0.134432
# 0.35   -0.083710
# 0.50    0.215727
# 0.70    0.674342
# 0.80    1.205151
# 0.95    4.274548
# Name: D/A_LxC, dtype: float64

# %%
print(her_met_CE['D/A_LA0147xP'].quantile([0.05,0.1,0.15,0.2 ,0.25,0.3 , 0.35 , 0.5,0.6 ,0.65,0.7,0.8 ,0.95,0.96]) ,
her_met_OR['D/A_LA0147xP'].quantile([0.05,0.1 ,0.11, 0.2 , 0.25 , 0.3 , 0.35 , 0.5 ,0.7,0.8 , 0.95]))
# Out:
# 0.05   -1.703198
# 0.10   -1.674659
# 0.15   -1.446064
# 0.20   -0.294502
# 0.25   -0.201339
# 0.30   -0.084410
# 0.35    0.013153
# 0.50    0.471970
# 0.60    0.795547
# 0.65    0.850146
# 0.70    1.044462
# 0.80    2.733419
# 0.95    8.134727
# 0.96    9.520422
# Name: D/A_LA0147xP, dtype: float64 0.05   -2.698349
# 0.10   -1.625393
# 0.11   -1.351469
# 0.20   -1.042553
# 0.25   -0.193223
# 0.30    0.374117
# 0.35    0.645870
# 0.50    1.095039
# 0.70    1.427658
# 0.80    2.139582
# 0.95    6.432684
# Name: D/A_LA0147xP, dtype: float64

# %%
print(her_met_CE['D/A_LA0147xP'].quantile([0.05 ,0.1,0.15 ,0.2 ,0.25 ,0.3 , 0.35 , 0.5,0.6 ,0.65,0.7,0.8 ,0.95]) ,
her_met_OR['D/A_LA0147xP'].quantile([0.05 , 0.1 ,0.11, 0.2 , 0.25 , 0.3 , 0.35 , 0.5 ,0.7,0.8 , 0.95]))
# Out:
# 0.05   -1.703198
# 0.10   -1.674659
# 0.15   -1.446064
# 0.20   -0.294502
# 0.25   -0.201339
# 0.30   -0.084410
# 0.35    0.013153
# 0.50    0.471970
# 0.60    0.795547
# 0.65    0.850146
# 0.70    1.044462
# 0.80    2.733419
# 0.95    8.134727
# Name: D/A_LA0147xP, dtype: float64 0.05   -2.698349
# 0.10   -1.625393
# 0.11   -1.351469
# 0.20   -1.042553
# 0.25   -0.193223
# 0.30    0.374117
# 0.35    0.645870
# 0.50    1.095039
# 0.70    1.427658
# 0.80    2.139582
# 0.95    6.432684
# Name: D/A_LA0147xP, dtype: float64

# %%
#aparenteemente, si uso el criterio heredado de pascual et al...

# %%
#[A = (P1-P2)/2]

#[D = H-((P1+P2)/2)]

#Levovil (P1) x Cervil (P2), LA0147 (P1) x Plovdiv (P2) and Ferum (P1) x LA1420 (P2)

# %%
#a priori, incluyo m'as datos de los que incluiria, si fuera astringente en mi criterio...

# %%
#por lo tanto , no veo mal usar dicho criterio en estos datos, ya que aparentemtne es una buena idea, 
#solo me queda chequear el tema de los NaN

# %%
her_met_CE.isna().any()
# Out:
# enzima           True
# A_LxC           False
# D_LxC           False
# D/A_LxC         False
# A_LA0147xP      False
# D_LA0147xP      False
# D/A_LA0147xP    False
# A_FxLA1420      False
# D_FxLA1420      False
# D/A_FxLA1420    False
# metabolito      False
# dtype: bool

# %%
her_met_OR.isna().any()
# Out:
# enzima           True
# A_LxC           False
# D_LxC           False
# D/A_LxC         False
# A_LA0147xP      False
# D_LA0147xP      False
# D/A_LA0147xP    False
# A_FxLA1420      False
# D_FxLA1420      False
# D/A_FxLA1420    False
# metabolito      False
# dtype: bool

# %%
her_AE_OR.isna().any()
# Out:
# enzima          False
# A_LxC           False
# D_LxC           False
# D/A_LxC         False
# A_LA0147xP      False
# D_LA0147xP      False
# D/A_LA0147xP    False
# A_FxLA1420      False
# D_FxLA1420      False
# D/A_FxLA1420    False
# dtype: bool

# %%
her_AE_CE.isna().any()
# Out:
# enzima          False
# A_LxC           False
# D_LxC           False
# D/A_LxC         False
# A_LA0147xP      False
# D_LA0147xP      False
# D/A_LA0147xP    False
# A_FxLA1420      False
# D_FxLA1420      False
# D/A_FxLA1420    False
# dtype: bool

# %%
#excelente!!!  como no hay nans, soy feliz!!!

# %%
#solo queda el analsiis
